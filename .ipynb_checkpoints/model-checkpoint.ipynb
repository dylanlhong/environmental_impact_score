# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16104 entries, 0 to 16103
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         16104 non-null  int64
#  1   iso2c              16043 non-null  object
#  2   country            16104 non-null  object
#  3   year               16104 non-null  int64
#  4   EN.ATM.PM25.MC.M3  2880 non-null   float64
#  5   EN.ATM.PM25.MC.ZS  2880 non-null   float64
#  6   EG.EGY.PRIM.PP.KD  4970 non-null   float64
#  7   EG.FEC.RNEW.ZS     6588 non-null   float64
#  8   EG.ELC.RNEW.ZS     6838 non-null   float64
#  9   EG.ELC.ACCS.ZS     6174 non-null   float64
#  10  EG.CFT.ACCS.ZS     3995 non-null   float64
#  11  AG.LND.FRST.ZS     6857 non-null   float64
#  12  NY.GDP.TOTL.RT.ZS  10816 non-null  float64
#  13  ER.LND.PTLD.ZS     770 non-null    float64
#  14  ER.PTD.TOTL.ZS     769 non-null    float64
#  15  ER.MRN.PTMR.ZS     607 non-null    float64
#  16  EG.ELC.ACCS.UR.ZS  6127 non-null   float64
#  17  SH.H2O.BASW.UR.ZS  3942 non-null   float64
#  18  SH.STA.BASS.UR.ZS  3908 non-null   float64
#  19  EG.ELC.ACCS.RU.ZS  5959 non-null   float64
#  20  SH.STA.BASS.RU.ZS  3783 non-null   float64
#  21  SH.H2O.BASW.RU.ZS  3774 non-null   float64
#  22  ER.H2O.INTR.PC     2540 non-null   float64
#  23  SH.H2O.SMDW.ZS     2210 non-null   float64
#  24  SH.STA.SMSS.ZS     2058 non-null   float64
#  25  iso3c              15860 non-null  object
#  26  region             15860 non-null  object
#  27  capital            12749 non-null  object
#  28  longitude          12749 non-null  float64
#  29  latitude           12749 non-null  float64
#  30  income             15860 non-null  object
#  31  lending            15860 non-null  object
# dtypes: float64(23), int64(2), object(7)
# memory usage: 3.9+ MB

# %%
# Import data
df_wdi = pd.read_csv('WDI-Environment-No-Commas.csv', encoding='utf-8', sep=";")
df_esg = pd.read_csv('ESGData.csv')

df_wdi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16104 entries, 0 to 16103
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         16104 non-null  int64
#  1   iso2c              16043 non-null  object
#  2   country            16104 non-null  object
#  3   year               16104 non-null  int64
#  4   EN.ATM.PM25.MC.M3  2880 non-null   float64
#  5   EN.ATM.PM25.MC.ZS  2880 non-null   float64
#  6   EG.EGY.PRIM.PP.KD  4970 non-null   float64
#  7   EG.FEC.RNEW.ZS     6588 non-null   float64
#  8   EG.ELC.RNEW.ZS     6838 non-null   float64
#  9   EG.ELC.ACCS.ZS     6174 non-null   float64
#  10  EG.CFT.ACCS.ZS     3995 non-null   float64
#  11  AG.LND.FRST.ZS     6857 non-null   float64
#  12  NY.GDP.TOTL.RT.ZS  10816 non-null  float64
#  13  ER.LND.PTLD.ZS     770 non-null    float64
#  14  ER.PTD.TOTL.ZS     769 non-null    float64
#  15  ER.MRN.PTMR.ZS     607 non-null    float64
#  16  EG.ELC.ACCS.UR.ZS  6127 non-null   float64
#  17  SH.H2O.BASW.UR.ZS  3942 non-null   float64
#  18  SH.STA.BASS.UR.ZS  3908 non-null   float64
#  19  EG.ELC.ACCS.RU.ZS  5959 non-null   float64
#  20  SH.STA.BASS.RU.ZS  3783 non-null   float64
#  21  SH.H2O.BASW.RU.ZS  3774 non-null   float64
#  22  ER.H2O.INTR.PC     2540 non-null   float64
#  23  SH.H2O.SMDW.ZS     2210 non-null   float64
#  24  SH.STA.SMSS.ZS     2058 non-null   float64
#  25  iso3c              15860 non-null  object
#  26  region             15860 non-null  object
#  27  capital            12749 non-null  object
#  28  longitude          12749 non-null  float64
#  29  latitude           12749 non-null  float64
#  30  income             15860 non-null  object
#  31  lending            15860 non-null  object
# dtypes: float64(23), int64(2), object(7)
# memory usage: 3.9+ MB

# %%
# Fix esg data to follow format of country and year as unit

# Create an empty DataFrame with no columns
df_new_esg = pd.DataFrame()
df_new_esg['country'] = None 

# Start at negative one to offset +1 for first row where value hasn't been placed yet
country_index = -1

# Each row is a country and one indicator variable, listing values for each year 1960 to 2020
for i in range(len(df_esg)):
    country = df_esg.loc[i, 'Country Name']
    indicator_code = df_esg.loc[i, 'Indicator Code']

    # Check if country name exists in dataframe already
    if not (df_new_esg['country'] == country).any():
        country_index += 1

    # Iterate through years in the row
    for j in range(1960, 2021):
        year_value = df_esg.loc[i, str(j)]

        # Add country and year to dataframe
        df_new_esg.loc[(country_index*61)+(j-1960), 'country'] = country
        df_new_esg.loc[(country_index*61)+(j-1960), 'year'] = j

        # Add new indicator value to dataframe
        df_new_esg.loc[(country_index*61)+(j-1960), str(indicator_code)] = year_value
df_new_esg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14579 entries, 0 to 14578
# Data columns (total 69 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country            14579 non-null  object
#  1   year               14579 non-null  float64
#  2   EG.CFT.ACCS.ZS     3995 non-null   float64
#  3   EG.ELC.ACCS.ZS     5599 non-null   float64
#  4   NY.ADJ.DRES.GN.ZS  8949 non-null   float64
#  5   NY.ADJ.DFOR.GN.ZS  9393 non-null   float64
#  6   AG.LND.AGRI.ZS     12076 non-null  float64
#  7   NV.AGR.TOTL.ZS     9400 non-null   float64
#  8   ER.H2O.FWTL.ZS     670 non-null    float64
#  9   SI.SPR.PCAP.ZG     92 non-null     float64
#  10  SH.DTH.COMM.ZS     916 non-null    float64
#  11  SL.TLF.0714.ZS     281 non-null    float64
#  12  EN.ATM.CO2E.PC     12289 non-null  float64
#  13  CC.EST             3970 non-null   float64
#  14  EN.CLC.CDDY.XD     0 non-null      float64
#  15  EN.CLC.MDAT.ZS     165 non-null    float64
#  16  IC.BUS.EASE.XQ     185 non-null    float64
#  17  EG.ELC.COAL.ZS     7895 non-null   float64
#  18  EG.IMP.CONS.ZS     8015 non-null   float64
#  19  EG.EGY.PRIM.PP.KD  4826 non-null   float64
#  20  EG.USE.PCAP.KG.OE  7743 non-null   float64
#  21  SP.DYN.TFRT.IN     13492 non-null  float64
#  22  AG.PRD.FOOD.XD     11938 non-null  float64
#  23  AG.LND.FRST.ZS     6346 non-null   float64
#  24  EG.USE.COMM.FO.ZS  8000 non-null   float64
#  25  NY.GDP.MKTP.KD.ZG  11363 non-null  float64
#  26  EN.CLC.GHGR.MT.CE  941 non-null    float64
#  27  SI.POV.GINI        1629 non-null   float64
#  28  GE.EST             3961 non-null   float64
#  29  SE.XPD.TOTL.GB.ZS  3395 non-null   float64
#  30  EN.CLC.HEAT.XD     0 non-null      float64
#  31  SH.MED.BEDS.ZS     4858 non-null   float64
#  32  SI.DST.FRST.20     1628 non-null   float64
#  33  IT.NET.USER.ZS     7153 non-null   float64
#  34  SL.TLF.ACTI.ZS     6720 non-null   float64
#  35  SP.DYN.LE00.IN     13492 non-null  float64
#  36  SE.ADT.LITR.ZS     2470 non-null   float64
#  37  EN.MAM.THRD.NO     239 non-null    float64
#  38  EN.CLC.PRCP.XD     0 non-null      float64
#  39  EN.CLC.SPEI.XD     0 non-null      float64
#  40  EN.ATM.METH.PC     9978 non-null   float64
#  41  SH.DYN.MORT        11790 non-null  float64
#  42  SM.POP.NETM        2748 non-null   float64
#  43  EN.ATM.NOXE.PC     10021 non-null  float64
#  44  IP.PAT.RESD        4679 non-null   float64
#  45  SH.H2O.SMDW.ZS     2030 non-null   float64
#  46  SH.STA.SMSS.ZS     1977 non-null   float64
#  47  EN.ATM.PM25.MC.M3  2784 non-null   float64
#  48  PV.EST             3992 non-null   float64
#  49  SP.POP.65UP.TO.ZS  13702 non-null  float64
#  50  EN.POP.DNST        13603 non-null  float64
#  51  SI.POV.NAHC        1064 non-null   float64
#  52  SH.STA.OWAD.ZS     9828 non-null   float64
#  53  SN.ITK.DEFC.ZS     3505 non-null   float64
#  54  SG.GEN.PARL.ZS     5391 non-null   float64
#  55  SL.TLF.CACT.FM.ZS  6720 non-null   float64
#  56  RQ.EST             3962 non-null   float64
#  57  EG.ELC.RNEW.ZS     6214 non-null   float64
#  58  EG.FEC.RNEW.ZS     6062 non-null   float64
#  59  GB.XPD.RSDV.GD.ZS  2466 non-null   float64
#  60  RL.EST             4028 non-null   float64
#  61  SE.PRM.ENRR        9613 non-null   float64
#  62  SE.ENR.PRSC.FM.ZS  7642 non-null   float64
#  63  IP.JRN.ARTC.SC     4541 non-null   float64
#  64  IC.LGL.CRED.XQ     1617 non-null   float64
#  65  ER.PTD.TOTL.ZS     709 non-null    float64
#  66  SL.UEM.TOTL.ZS     6720 non-null   float64
#  67  SP.UWT.TFRT        629 non-null    float64
#  68  VA.EST             4040 non-null   float64
# dtypes: float64(68), object(1)
# memory usage: 8.3+ MB

# %%
# Merge the data

# Merge on country and year with outer to keep all entities
data = df_wdi.merge(df_new_esg, on=['country', 'year'], how='outer')

# Save the combined DataFrame to a new CSV file
data.to_csv('Data.csv', index=False)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17080 entries, 0 to 17079
# Data columns (total 99 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           16104 non-null  float64
#  1   iso2c                16043 non-null  object
#  2   country              17080 non-null  object
#  3   year                 17080 non-null  float64
#  4   EN.ATM.PM25.MC.M3_x  2880 non-null   float64
#  5   EN.ATM.PM25.MC.ZS    2880 non-null   float64
#  6   EG.EGY.PRIM.PP.KD_x  4970 non-null   float64
#  7   EG.FEC.RNEW.ZS_x     6588 non-null   float64
#  8   EG.ELC.RNEW.ZS_x     6838 non-null   float64
#  9   EG.ELC.ACCS.ZS_x     6174 non-null   float64
#  10  EG.CFT.ACCS.ZS_x     3995 non-null   float64
#  11  AG.LND.FRST.ZS_x     6857 non-null   float64
#  12  NY.GDP.TOTL.RT.ZS    10816 non-null  float64
#  13  ER.LND.PTLD.ZS       770 non-null    float64
#  14  ER.PTD.TOTL.ZS_x     769 non-null    float64
#  15  ER.MRN.PTMR.ZS       607 non-null    float64
#  16  EG.ELC.ACCS.UR.ZS    6127 non-null   float64
#  17  SH.H2O.BASW.UR.ZS    3942 non-null   float64
#  18  SH.STA.BASS.UR.ZS    3908 non-null   float64
#  19  EG.ELC.ACCS.RU.ZS    5959 non-null   float64
#  20  SH.STA.BASS.RU.ZS    3783 non-null   float64
#  21  SH.H2O.BASW.RU.ZS    3774 non-null   float64
#  22  ER.H2O.INTR.PC       2540 non-null   float64
#  23  SH.H2O.SMDW.ZS_x     2210 non-null   float64
#  24  SH.STA.SMSS.ZS_x     2058 non-null   float64
#  25  iso3c                15860 non-null  object
#  26  region               15860 non-null  object
#  27  capital              12749 non-null  object
#  28  longitude            12749 non-null  float64
#  29  latitude             12749 non-null  float64
#  30  income               15860 non-null  object
#  31  lending              15860 non-null  object
#  32  EG.CFT.ACCS.ZS_y     3995 non-null   float64
#  33  EG.ELC.ACCS.ZS_y     5599 non-null   float64
#  34  NY.ADJ.DRES.GN.ZS    8949 non-null   float64
#  35  NY.ADJ.DFOR.GN.ZS    9393 non-null   float64
#  36  AG.LND.AGRI.ZS       12076 non-null  float64
#  37  NV.AGR.TOTL.ZS       9400 non-null   float64
#  38  ER.H2O.FWTL.ZS       670 non-null    float64
#  39  SI.SPR.PCAP.ZG       92 non-null     float64
#  40  SH.DTH.COMM.ZS       916 non-null    float64
#  41  SL.TLF.0714.ZS       281 non-null    float64
#  42  EN.ATM.CO2E.PC       12289 non-null  float64
#  43  CC.EST               3970 non-null   float64
#  44  EN.CLC.CDDY.XD       0 non-null      float64
#  45  EN.CLC.MDAT.ZS       165 non-null    float64
#  46  IC.BUS.EASE.XQ       185 non-null    float64
#  47  EG.ELC.COAL.ZS       7895 non-null   float64
#  48  EG.IMP.CONS.ZS       8015 non-null   float64
#  49  EG.EGY.PRIM.PP.KD_y  4826 non-null   float64
#  50  EG.USE.PCAP.KG.OE    7743 non-null   float64
#  51  SP.DYN.TFRT.IN       13492 non-null  float64
#  52  AG.PRD.FOOD.XD       11938 non-null  float64
#  53  AG.LND.FRST.ZS_y     6346 non-null   float64
#  54  EG.USE.COMM.FO.ZS    8000 non-null   float64
#  55  NY.GDP.MKTP.KD.ZG    11363 non-null  float64
#  56  EN.CLC.GHGR.MT.CE    941 non-null    float64
#  57  SI.POV.GINI          1629 non-null   float64
#  58  GE.EST               3961 non-null   float64
#  59  SE.XPD.TOTL.GB.ZS    3395 non-null   float64
#  60  EN.CLC.HEAT.XD       0 non-null      float64
#  61  SH.MED.BEDS.ZS       4858 non-null   float64
#  62  SI.DST.FRST.20       1628 non-null   float64
#  63  IT.NET.USER.ZS       7153 non-null   float64
#  64  SL.TLF.ACTI.ZS       6720 non-null   float64
#  65  SP.DYN.LE00.IN       13492 non-null  float64
#  66  SE.ADT.LITR.ZS       2470 non-null   float64
#  67  EN.MAM.THRD.NO       239 non-null    float64
#  68  EN.CLC.PRCP.XD       0 non-null      float64
#  69  EN.CLC.SPEI.XD       0 non-null      float64
#  70  EN.ATM.METH.PC       9978 non-null   float64
#  71  SH.DYN.MORT          11790 non-null  float64
#  72  SM.POP.NETM          2748 non-null   float64
#  73  EN.ATM.NOXE.PC       10021 non-null  float64
#  74  IP.PAT.RESD          4679 non-null   float64
#  75  SH.H2O.SMDW.ZS_y     2030 non-null   float64
#  76  SH.STA.SMSS.ZS_y     1977 non-null   float64
#  77  EN.ATM.PM25.MC.M3_y  2784 non-null   float64
#  78  PV.EST               3992 non-null   float64
#  79  SP.POP.65UP.TO.ZS    13702 non-null  float64
#  80  EN.POP.DNST          13603 non-null  float64
#  81  SI.POV.NAHC          1064 non-null   float64
#  82  SH.STA.OWAD.ZS       9828 non-null   float64
#  83  SN.ITK.DEFC.ZS       3505 non-null   float64
#  84  SG.GEN.PARL.ZS       5391 non-null   float64
#  85  SL.TLF.CACT.FM.ZS    6720 non-null   float64
#  86  RQ.EST               3962 non-null   float64
#  87  EG.ELC.RNEW.ZS_y     6214 non-null   float64
#  88  EG.FEC.RNEW.ZS_y     6062 non-null   float64
#  89  GB.XPD.RSDV.GD.ZS    2466 non-null   float64
#  90  RL.EST               4028 non-null   float64
#  91  SE.PRM.ENRR          9613 non-null   float64
#  92  SE.ENR.PRSC.FM.ZS    7642 non-null   float64
#  93  IP.JRN.ARTC.SC       4541 non-null   float64
#  94  IC.LGL.CRED.XQ       1617 non-null   float64
#  95  ER.PTD.TOTL.ZS_y     709 non-null    float64
#  96  SL.UEM.TOTL.ZS       6720 non-null   float64
#  97  SP.UWT.TFRT          629 non-null    float64
#  98  VA.EST               4040 non-null   float64
# dtypes: float64(92), object(7)
# memory usage: 12.9+ MB

# %%
# Explore data: Seaborn/Plotly (eg. histograms)

# Count the number of data points for each region
ax = sns.countplot(x='region', data=data);

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
                textcoords='offset points')

plt.xticks(rotation=45);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 5
#       1 # Explore data: Seaborn/Plotly (eg. histograms)
#       2
#       3 # Count the number of data points for each region
#       4 ax = sns.countplot(x='region', data=data);
# ----> 5 ax.xticks(rotation=45);
#       7 for p in ax.patches:
#       8     ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
#       9                 ha='center', va='center', fontsize=11, color='black', xytext=(0, 5),
#      10                 textcoords='offset points')
#
# AttributeError: 'Axes' object has no attribute 'xticks'
